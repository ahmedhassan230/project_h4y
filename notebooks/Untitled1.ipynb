# %%
# !pip install nltk spacy scikit-learn
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: nltk in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (3.8.1)
# Collecting spacy
#   Downloading spacy-3.7.5-cp310-cp310-macosx_11_0_arm64.whl.metadata (27 kB)
# Requirement already satisfied: scikit-learn in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (1.3.1)
# Requirement already satisfied: click in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from nltk) (4.66.4)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Downloading murmurhash-1.0.10-cp310-cp310-macosx_11_0_arm64.whl.metadata (2.0 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Downloading cymem-2.0.8-cp310-cp310-macosx_11_0_arm64.whl.metadata (8.4 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Downloading preshed-3.0.9-cp310-cp310-macosx_11_0_arm64.whl.metadata (2.2 kB)
# Collecting thinc<8.3.0,>=8.2.2 (from spacy)
#   Downloading thinc-8.2.4-cp310-cp310-macosx_11_0_arm64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Downloading wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy)
#   Downloading srsly-2.4.8-cp310-cp310-macosx_11_0_arm64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.5.0,>=0.1.0 (from spacy)
#   Downloading weasel-0.4.1-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from spacy) (0.12.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from spacy) (2.32.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from spacy) (2.7.2)
# Requirement already satisfied: jinja2 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from spacy) (63.2.0)
# Requirement already satisfied: packaging>=20.0 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from spacy) (24.0)
# Collecting langcodes<4.0.0,>=3.2.0 (from spacy)
#   Downloading langcodes-3.4.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: numpy>=1.19.0 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from spacy) (1.23.5)
# Requirement already satisfied: scipy>=1.5.0 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from scikit-learn) (1.10.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from scikit-learn) (3.5.0)
# Collecting language-data>=1.2 (from langcodes<4.0.0,>=3.2.0->spacy)
#   Downloading language_data-1.2.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.3 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.18.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.2.2)
# Collecting blis<0.8.0,>=0.7.8 (from thinc<8.3.0,>=8.2.2->spacy)
#   Downloading blis-0.7.11-cp310-cp310-macosx_11_0_arm64.whl.metadata (7.4 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.3.0,>=8.2.2->spacy)
#   Downloading confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.7.1)
# Collecting cloudpathlib<1.0.0,>=0.7.0 (from weasel<0.5.0,>=0.1.0->spacy)
#   Downloading cloudpathlib-0.18.1-py3-none-any.whl.metadata (14 kB)
# Collecting smart-open<8.0.0,>=5.2.1 (from weasel<0.5.0,>=0.1.0->spacy)
#   Downloading smart_open-7.0.4-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from jinja2->spacy) (2.1.5)
# Collecting marisa-trie>=0.7.7 (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy)
#   Downloading marisa_trie-1.1.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (8.6 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Collecting wrapt (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy)
#   Using cached wrapt-1.16.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: mdurl~=0.1 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Downloading spacy-3.7.5-cp310-cp310-macosx_11_0_arm64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 26.0 MB/s eta 0:00:00a 0:00:01
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading cymem-2.0.8-cp310-cp310-macosx_11_0_arm64.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 kB 1.9 MB/s eta 0:00:00
# Downloading langcodes-3.4.0-py3-none-any.whl (182 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.0/182.0 kB 20.8 MB/s eta 0:00:00
# Downloading murmurhash-1.0.10-cp310-cp310-macosx_11_0_arm64.whl (26 kB)
# Downloading preshed-3.0.9-cp310-cp310-macosx_11_0_arm64.whl (127 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.8/127.8 kB 8.4 MB/s eta 0:00:00
# Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.4.8-cp310-cp310-macosx_11_0_arm64.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.2/491.2 kB 17.2 MB/s eta 0:00:00
# Downloading thinc-8.2.4-cp310-cp310-macosx_11_0_arm64.whl (789 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 789.6/789.6 kB 27.4 MB/s eta 0:00:00
# Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Downloading weasel-0.4.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.3/50.3 kB 2.8 MB/s eta 0:00:00
# Downloading blis-0.7.11-cp310-cp310-macosx_11_0_arm64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 30.2 MB/s eta 0:00:00
# Downloading cloudpathlib-0.18.1-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.3/47.3 kB 3.4 MB/s eta 0:00:00
# Downloading confection-0.1.5-py3-none-any.whl (35 kB)
# Downloading language_data-1.2.0-py3-none-any.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 34.6 MB/s eta 0:00:0000:0100:01
# Downloading smart_open-7.0.4-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 5.3 MB/s eta 0:00:00
# Downloading marisa_trie-1.1.1-cp310-cp310-macosx_11_0_arm64.whl (174 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.9/174.9 kB 8.5 MB/s eta 0:00:00
# Using cached wrapt-1.16.0-cp310-cp310-macosx_11_0_arm64.whl (38 kB)
# Installing collected packages: cymem, wrapt, wasabi, spacy-loggers, spacy-legacy, murmurhash, marisa-trie, cloudpathlib, catalogue, blis, srsly, smart-open, preshed, language-data, langcodes, confection, weasel, thinc, spacy
# Successfully installed blis-0.7.11 catalogue-2.0.10 cloudpathlib-0.18.1 confection-0.1.5 cymem-2.0.8 langcodes-3.4.0 language-data-1.2.0 marisa-trie-1.1.1 murmurhash-1.0.10 preshed-3.0.9 smart-open-7.0.4 spacy-3.7.5 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.4.8 thinc-8.2.4 wasabi-1.1.3 weasel-0.4.1 wrapt-1.16.0
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 20.6 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from en-core-web-sm==3.7.1) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.12.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.32.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.7.2)
# Requirement already satisfied: jinja2 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.4)
# Requirement already satisfied: setuptools in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (63.2.0)
# Requirement already satisfied: packaging>=20.0 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.23.5)
# Requirement already satisfied: language-data>=1.2 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.3 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.18.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.12.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.18.0)
# Requirement already satisfied: wrapt in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/srividhyaleeladharan/.pyenv/versions/3.10.6/envs/project_4y/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.2)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.7.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import nltk
import spacy
from sklearn.feature_extraction.text import TfidfVectorizer
import string

# Load SpaCy English model
nlp = spacy.load("en_core_web_sm")

# Example health-related post content
post_content = """
Regular exercise is essential for maintaining overall health. It helps control weight, reduces the risk of heart disease,
and strengthens bones and muscles. Additionally, physical activity can improve mental health by reducing anxiety, depression,
and negative mood. Incorporating a balanced diet rich in fruits and vegetables also supports a healthy lifestyle.
"""

# Preprocess the text
def preprocess_text(text):
    # Remove punctuation and convert to lowercase
    text = text.translate(str.maketrans('', '', string.punctuation)).lower()
    return text

preprocessed_text = preprocess_text(post_content)

# Function to extract keywords using TF-IDF
def extract_keywords(text, num_keywords=10):
    vectorizer = TfidfVectorizer(stop_words='english')
    tfidf_matrix = vectorizer.fit_transform([text])
    feature_names = vectorizer.get_feature_names_out()
    tfidf_scores = tfidf_matrix.toarray()[0]

    # Get top n keywords based on TF-IDF scores
    sorted_indices = tfidf_scores.argsort()[::-1]
    top_keywords = [feature_names[idx] for idx in sorted_indices[:num_keywords]]
    return top_keywords

# Extract keywords
keywords = extract_keywords(preprocessed_text)
print("Keywords:", keywords)

# Function to extract named entities
def extract_entities(text):
    doc = nlp(text)
    entities = [entity.text for entity in doc.ents if entity.label_ in ['PERSON', 'ORG', 'GPE', 'DATE', 'TIME', 'MONEY', 'QUANTITY', 'ORDINAL', 'CARDINAL']]
    return entities

# Extract entities
entities = extract_entities(post_content)
print("Entities:", entities)

# Combine keywords and entities
tags = list(set(keywords + entities))
print("Tags:", tags)

# Health-specific filtering (if needed)
health_specific_tags = [tag for tag in tags if tag not in ['time', 'date', 'money']]  # Example of filtering out non-health-related tags

# Add manual tags if necessary
manual_tags = ['health', 'exercise', 'diet', 'mental health']
final_tags = list(set(health_specific_tags + manual_tags))

print("Final Tags:", final_tags)
# Out:
# Keywords: ['health', 'weight', 'disease', 'heart', 'healthy', 'fruits', 'exercise', 'essential', 'diet', 'improve']
# Entities: []
# Tags: ['improve', 'essential', 'exercise', 'healthy', 'weight', 'heart', 'disease', 'diet', 'health', 'fruits']
# Final Tags: ['improve', 'essential', 'exercise', 'healthy', 'weight', 'heart', 'disease', 'diet', 'mental health', 'health', 'fruits']

# %%
# !pwd
# Out:
# /Users/srividhyaleeladharan/code/project_h4y/notebooks

# %%
import pandas as pd
data=pd.read_csv('../raw_data/fake_posts.csv')

# %%
data['Content']=data['Content'].apply(preprocess_text)

# %%
data.head()
# Out:
#                                                Title  \
# 0     Let's Talk about the Importance of Foot Care\n
# 1   Random Health Benefits of Practicing Tai Chi\n\n
# 2  Get Your Heart Pumping with These Seasonal Fit...
# 3      The Power of Herbal Teas for Optimal Health\n
# 4           The Ins and Outs of Proper Handwashing\n
#
#                                              Content  Category  \
# 0  hey there health enthusiasts today lets chat a...  diabetes
# 1  hey guys its your favorite health and lifestyl...   generic
# 2  hey there fitness enthusiasts today im here to...  diabetes
# 3  hey health enthusiast friends today i want to ...  diabetes
# 4  yo yo yo what up my peeps today i wanna talk t...   generic
#
#                                                 Tags
# 0  !Checkups !FootCare !HeartDiet !Vaccines !Type...
# 1  !Exercise !Vaccines !Resilience !Cholesterol !...
# 2  !Fitness !Seasonal !DiabetesPrevention !Exerci...
# 3     !Hydration !Glucose !Fitness !Vitamins !Cardio
# 4  !Stress !FootCare !Happiness !PhysicalTherapy ...

# %%
data.head()
# Out:
#                                                Title  \
# 0     Let's Talk about the Importance of Foot Care\n
# 1   Random Health Benefits of Practicing Tai Chi\n\n
# 2  Get Your Heart Pumping with These Seasonal Fit...
# 3      The Power of Herbal Teas for Optimal Health\n
# 4           The Ins and Outs of Proper Handwashing\n
#
#                                              Content  Category  \
# 0  hey there health enthusiasts today lets chat a...  diabetes
# 1  hey guys its your favorite health and lifestyl...   generic
# 2  hey there fitness enthusiasts today im here to...  diabetes
# 3  hey health enthusiast friends today i want to ...  diabetes
# 4  yo yo yo what up my peeps today i wanna talk t...   generic
#
#                                                 Tags  \
# 0  !Checkups !FootCare !HeartDiet !Vaccines !Type...
# 1  !Exercise !Vaccines !Resilience !Cholesterol !...
# 2  !Fitness !Seasonal !DiabetesPrevention !Exerci...
# 3     !Hydration !Glucose !Fitness !Vitamins !Cardio
# 4  !Stress !FootCare !Happiness !PhysicalTherapy ...
#
#                                             keywords  \
# 0  [lets, health, foot, care, crucial, managing, ...
# 1  [tai, chi, improve, help, health, lets, way, e...
# 2  [active, exercise, fall, like, fitness, blood,...
# 3  [teas, herbal, tea, body, health, like, levels...
# 4  [hands, handwashing, know, youre, germs, yo, y...
#
#                                             entities  \
# 0                              [today, 2, omega3, 2]
# 1                            [today, first, tai chi]
# 2  [today, summer fall, winter, spring, daily, on...
# 3                                     [today, daily]
# 4  [yo yo yo, today, first, first, at least 20 se...
#
#                                                 tags
# 0  [diabetes, managing, checkups, crucial, today,...
# 1  [improve, exercise, stay, talk, today, tai, le...
# 2  [blood, daily, like, exercise, fall, staying, ...
# 3  [daily, like, today, levels, vitamins, cardio,...
# 4  [yo yo yo, at least 20 seconds, germs, aint, c...

# %%
data['keywords']=data['Content'].apply(extract_keywords)

# %%
data['entities']=data['Content'].apply(extract_entities)

# %%
def tags(keywords, entities):
    return list(set(keywords + entities))

# Apply the tags function to create the tags column
data['tags'] = data.apply(lambda row: tags(row['keywords'], row['entities']), axis=1)

# %%
'distress', 'tension','anxiety', 'fatigue', 'pressure', 'relaxation','Calm','Peaceful','Tranquil','Serene','Composed','Carefree','Easygoing','Laidback','Meditation','Yoga','Vacation','Spa','Massage','Reading','NatureWalks','Bathing','BreathingExercises','Mindfulness','Aromatherapy','Unwind','glucose','diabetes','nutrition','insulin', 'hypoglycaemia','chest pain','heartattack', 'heart','CVD', 'blood pressure', 'heart failure', 'heart attack', 'pain', 'fracture', 'back pain', 'joint pain', 'trauma', 'bone', 'bone density', 'bone loss', 'muscle pain', 'Sports', 'injury','cardiovascular diseases','IntermittentFasting','KetoDiet','Superfoods','OrganicFoods','Vegan','nutrition','worklifebalance','hygienepractices','acupuncture','minimalism'

# %%
def health_specific_tags(tags):
    t=['vaccines','therapy','muscles','routine','wellbeing','selfcare','bones','fracture','pain','arthritis','cholesterol','stress','mindfulness','depression','mood','osteoporosis','challenges','lifestyle','healthy','diet','greens','wellbeing','handwashing','cleanliness','aging','vitamins','joints','health','calcium','insulin','workout','cardio','exercise','checkups','recovery','distress', 'tension','anxiety', 'fatigue', 'pressure', 'relaxation','Calm','Peaceful','Tranquil','Serene','Composed','Carefree','Easygoing','Laidback','Meditation','Yoga','Vacation','Spa','Massage','Reading','NatureWalks','Bathing','BreathingExercises','Mindfulness','Aromatherapy','Unwind','glucose','diabetes','nutrition','insulin', 'hypoglycaemia','chest pain','heartattack', 'heart','CVD', 'blood pressure', 'heart failure', 'heart attack', 'pain', 'fracture', 'back pain', 'joint pain', 'trauma', 'bone', 'bone density', 'bone loss', 'muscle pain', 'Sports', 'injury','cardiovascular diseases','IntermittentFasting','KetoDiet','Superfoods','OrganicFoods','Vegan','nutrition','worklifebalance','hygienepractices','acupuncture','minimalism']
    t_lower=[tag.lower() for tag in t]
    tag_list= [tag for tag in tags if tag in t ]
    return tag_list

# %%
data['final_tags']=data['tags'].apply(health_specific_tags)

# %%
data.tags
# Out:
# 0      [diabetes, managing, checkups, crucial, today,...
# 1      [improve, exercise, stay, talk, today, tai, le...
# 2      [blood, daily, like, exercise, fall, staying, ...
# 3      [daily, like, today, levels, vitamins, cardio,...
# 4      [yo yo yo, at least 20 seconds, germs, aint, c...
#                              ...
# 994    [calcium, joint, daily, like, prevent, one, he...
# 995    [diabetes, 1, time, body, sugar, youre, surger...
# 996    [aging, inside, today, vitamins, one, summer, ...
# 997    [improve, calcium, great, involved, insulin, t...
# 998    [rate, roller, recovery, workout, foam, today,...
# Name: tags, Length: 999, dtype: object

# %%
data
# Out:
#                                                  Title  \
# 0       Let's Talk about the Importance of Foot Care\n
# 1     Random Health Benefits of Practicing Tai Chi\n\n
# 2    Get Your Heart Pumping with These Seasonal Fit...
# 3        The Power of Herbal Teas for Optimal Health\n
# 4             The Ins and Outs of Proper Handwashing\n
# ..                                                 ...
# 994  The Importance of Lavender Oil for Joint Health\n
# 995  Be the Boss of Your Health with These 5 Lifest...
# 996  From Frail to Fabulous: A Guide to Aging Grace...
# 997    The Surprising Health Benefits of Gardening\n\n
# 998          The Surprising Benefits of Using a Foa...
#
#                                                Content  Category  \
# 0    hey there health enthusiasts today lets chat a...  diabetes
# 1    hey guys its your favorite health and lifestyl...   generic
# 2    hey there fitness enthusiasts today im here to...  diabetes
# 3    hey health enthusiast friends today i want to ...  diabetes
# 4    yo yo yo what up my peeps today i wanna talk t...   generic
# ..                                                 ...       ...
# 994  as a medical professional i cannot stress enou...  skeleton
# 995  hey there health warriors if youre looking to ...  diabetes
# 996  hey there all you fabulous individuals today l...  skeleton
# 997  hey everyone today i want to talk about the in...     heart
# 998  content\n        hey friends 👋 today i want to...  skeleton
#
#                                                   Tags  \
# 0    !Checkups !FootCare !HeartDiet !Vaccines !Type...
# 1    !Exercise !Vaccines !Resilience !Cholesterol !...
# 2    !Fitness !Seasonal !DiabetesPrevention !Exerci...
# 3       !Hydration !Glucose !Fitness !Vitamins !Cardio
# 4    !Stress !FootCare !Happiness !PhysicalTherapy ...
# ..                                                 ...
# 994                                                NaN
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
# 998                                                NaN
#
#                                               keywords  \
# 0    [lets, health, foot, care, crucial, managing, ...
# 1    [tai, chi, improve, help, health, lets, way, e...
# 2    [active, exercise, fall, like, fitness, blood,...
# 3    [teas, herbal, tea, body, health, like, levels...
# 4    [hands, handwashing, know, youre, germs, yo, y...
# ..                                                 ...
# 994  [joint, lavender, oil, joints, help, health, c...
# 995  [lets, health, hydration, youre, time, sugar, ...
# 996  [aging, lets, vitamins, osteoporosis, care, ag...
# 997  [gardening, youre, garden, improve, help, grea...
# 998  [foam, help, rolling, body, muscles, roller, k...
#
#                                               entities  \
# 0                                [today, 2, omega3, 2]
# 1                              [today, first, tai chi]
# 2    [today, summer fall, winter, spring, daily, on...
# 3                                       [today, daily]
# 4    [yo yo yo, today, first, first, at least 20 se...
# ..                                                 ...
# 994                                       [one, daily]
# 995                                          [2, 1, 5]
# 996                               [today, one, summer]
# 997                                            [today]
# 998          [👋, today, 🏋, a long day, selfcaresunday]
#
#                                                   tags  \
# 0    [diabetes, managing, checkups, crucial, today,...
# 1    [improve, exercise, stay, talk, today, tai, le...
# 2    [blood, daily, like, exercise, fall, staying, ...
# 3    [daily, like, today, levels, vitamins, cardio,...
# 4    [yo yo yo, at least 20 seconds, germs, aint, c...
# ..                                                 ...
# 994  [calcium, joint, daily, like, prevent, one, he...
# 995  [diabetes, 1, time, body, sugar, youre, surger...
# 996  [aging, inside, today, vitamins, one, summer, ...
# 997  [improve, calcium, great, involved, insulin, t...
# 998  [rate, roller, recovery, workout, foam, today,...
#
#                                   final_tags
# 0         [diabetes, checkups, diet, health]
# 1                         [exercise, health]
# 2                                 [exercise]
# 3                 [vitamins, cardio, health]
# 4                              [handwashing]
# ..                                       ...
# 994                [calcium, joints, health]
# 995                       [diabetes, health]
# 996  [aging, vitamins, osteoporosis, injury]
# 997                       [calcium, insulin]
# 998             [recovery, workout, muscles]
#
# [999 rows x 8 columns]

# %%
data.to_csv('../raw_data/tags.csv')
